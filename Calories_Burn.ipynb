# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\Edunet_internship\calories.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_21996\1534072525.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_csv("D:\Edunet_internship\calories.csv")
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_cal = df.drop('User_ID', axis=1)
df_cal
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
# [15000 rows x 8 columns]

# %%
fig=px.histogram(df_cal, x='Age', nbins=47, title='Age_Distribution')
fig.update_layout(bargap=0.05)
fig.show()

# %%
corr=df_cal.Age.corr(df_cal.Calories)
corr
# Out:
# 0.1543951313410012

# %%
fig=px.histogram(df_cal, x='Duration', nbins=47, marginal='box')
fig.update_layout(bargap=0.05)
fig.show()

# %%
corr=df_cal.Duration.corr(df_cal.Calories)
corr
# Out:
# 0.9554205334742683

# %%
fig=px.histogram(df_cal, x='Calories', color='Gender', nbins=47)
fig.update_layout(bargap=0.05)
fig

# %%
fig=px.scatter(df_cal, x='Age', y='Calories', color='Gender', title='Calories vs Age')
fig

# %%
fig=px.scatter(df_cal, x='Duration', y='Calories', color='Gender', title='Calories vs Duration')
fig

# %%
gender_val={'male':1, 'female':0}
df_cal['gender_num']=df_cal.Gender.map(gender_val)
df_cal
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# 0        male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1      female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2        male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3      female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4      female   27   154.0    58.0      10.0        81.0       39.8      35.0
# ...       ...  ...     ...     ...       ...         ...        ...       ...
# 14995  female   20   193.0    86.0      11.0        92.0       40.4      45.0
# 14996  female   27   165.0    65.0       6.0        85.0       39.2      23.0
# 14997  female   43   159.0    58.0      16.0        90.0       40.1      75.0
# 14998    male   78   193.0    97.0       2.0        84.0       38.3      11.0
# 14999    male   63   173.0    79.0      18.0        92.0       40.5      98.0
#
#        gender_num
# ...

# %%
corr=df_cal.Calories.corr(gender_num)
corr
# Out:
# 0.022357162090988817

# %%
fig=sns.scatterplot(df_cal, x='Duration', y='Calories', s=10)
fig
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
def rmse(target, predictions):
    return np.sqrt(np.mean(np.square(target-predictions)))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
inputs=df_cal[['Duration']]
outputs=df_cal.Calories
model.fit(inputs, outputs)
# Out:
# LinearRegression()

# %%
predictions=model.predict(inputs)
predictions
# Out:
# array([186.1539749 ,  78.56071733,  14.00476279, ...,  92.90648501,
#         -7.51388872, 107.25225268])

# %%
target=outputs
rmse(target, predictions)
# Out:
# 18.4397066961982

# %%
plt.scatter(inputs, target, alpha=0.5)
plt.plot(inputs, predictions, 'r-o', alpha=0.8)
plt.xlabel('Durations')
plt.ylabel('Calories_burn')
plt.show()

# %%
inputs=df_cal[['Heart_Rate']]
output=df_cal.Calories
model.fit(inputs, outputs)
# Out:
# LinearRegression()

# %%
predictions=model.predict(inputs)
print(np.min(predictions), np.max(predictions))
predictions
# Out:
# -77.34307791282441 279.6121401915061
# array([145.02246779,  80.65349403,  45.54314471, ...,  57.24659449,
#         22.13624517,  68.95004426])

# %%
target=output
rmse(target, predictions)
# Out:
# 27.494898534078196

# %%
plt.scatter(inputs, target, s=8, alpha=0.5)
plt.plot(inputs, predictions, 'r-o', alpha=0.8)
plt.xlabel('Heart_Rate')
plt.ylabel('Calories_burn')
plt.legend(['Actual', 'Prediction'])
plt.show()

# %%
inputs=df_cal[['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'gender_num']]
output=df_cal.Calories
model.fit(inputs, output)
# Out:
# LinearRegression()

# %%
predictions=model.predict(inputs)
predictions
# Out:
# array([199.57081917,  57.95182128,  40.02965852, ...,  78.86773729,
#         26.30108558, 101.84213879])

# %%
target=output
rmse(target, predictions)
# Out:
# 11.31086532154349

# %%
model.predict([[25, 180, 74, 25, 100, 45, 1]])
# Out:
# C:\Users\Rohan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([66.0101289])

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf=RandomForestRegressor()

# %%
inputs=df_cal[['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'gender_num']]
output=df_cal.Calories
model_rf.fit(inputs, output)
# Out:
# RandomForestRegressor()

# %%
predictions=model_rf.predict(inputs)
predictions
# Out:
# array([231.32,  66.49,  25.73, ...,  74.83,  10.49,  98.88])

# %%
target=output
loss=rmse(target, predictions)
print('RMSE LOSS:', loss)
# Out:
# RMSE LOSS: 1.0191555098871483

# %%
model_rf.predict([[25, 180, 84, 26, 100, 42, 1]])
# Out:
# C:\Users\Rohan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# array([126.36])

# %%
model_rf.predict([[54, 160.02, 74.6, 25, 100, 80, 0]])
# Out:
# C:\Users\Rohan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# array([147.36])

# %%
model_rf.predict([[60, 170.18, 80, 40, 80, 38, 1]])
# Out:
# C:\Users\Rohan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# array([177.05])
